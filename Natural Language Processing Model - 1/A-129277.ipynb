# %%
pip install nltk
# Out:
# Collecting nltkNote: you may need to restart the kernel to use updated packages.
#
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from nltk) (1.2.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp39-cp39-win_amd64.whl (267 kB)
#      -------------------------------------- 267.8/267.8 KB 1.4 MB/s eta 0:00:00
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python39\site-packages (from click->nltk) (0.4.5)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.7 regex-2022.10.31 tqdm-4.64.1
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\User\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

df=pd.read_csv('LAB3.csv')
df.head(20)
# Out:
#                 product                                          narrative
# 0   mortgages_and_loans  applied mortgage refinance understand process ...
# 1       debt_collection  received letter demanding payment medical debt...
# 2       debt_collection  car accident fault year old financial help use...
# 3       debt_collection  bad financial shape stemming bad employment si...
# 4       debt_collection  reliant capital solution repeatly call spouse ...
# 5       debt_collection  called company numerous time debt mine sent th...
# 6       debt_collection  mentioned debt collecting agency sent letter d...
# 7           credit_card  late fee accumulated nearly extra fee deferred...
# 8           credit_card  purchased ticket cancelled event requested ref...
# 9       debt_collection  national service bureau threatened jail time r...
# 10      debt_collection  transworld system called repeatedly explained ...
# 11      debt_collection  receiving phone call abc financial regarding o...
# 12       retail_banking  hello used transfer money closed account go ba...
# 13      debt_collection  mailed notice acceptance negotiable instrument...
# 14  mortgages_and_loans  made mortgage payment bank america using coupo...
# 15       retail_banking  may concern take corrective action believe squ...
# 16  mortgages_and_loans  signed va refinance loan pennymac set closing ...
# 17          credit_card  hi thank helping relia debit card issued unemp...
# 18       retail_banking  applied cash loan lending club unaware would m...
# 19  mortgages_and_loans  applied refinance fha loan conventional loan c...

# %%
df.sample(50)
# Out:
#                    product                                          narrative
# 959        debt_collection  received letter credence weekend saying collec...
# 65520       retail_banking  charged product returned charged extra hour me...
# 12399      debt_collection  notice demand cease desist collection activity...
# 30617       retail_banking  victim wire fraud scam closing family new home...
# 46933  mortgages_and_loans  graduated school consolidated federal loan loa...
# 52036      debt_collection  recently received noticed farmar law group rep...
# 25508       retail_banking  say pnc authorize link debit card round change...
# 29625  mortgages_and_loans  victim identity theft granite state mgmt unrig...
# 23725  mortgages_and_loans  applied forbearance mortgage behind wanted mak...
# 52790       retail_banking  name address writing locked u reliacard accoun...
# 37842       retail_banking  checked account there multiple transaction fil...
# 3774       debt_collection  today date attention dispute department ar acc...
# 107        debt_collection  knowledge account requested original date acco...
# 49443  mortgages_and_loans  continue submit principal payment monthly basi...
# 68492          credit_card  open credit card capitalone identity theft tri...
# 2244       debt_collection  ask company validate debt could reporting ille...
# 10960      debt_collection  pcr kept calling regard owe nebraska universit...
# 42401      debt_collection  received notice dated judgement creditor midla...
# 4938           credit_card  started receiving fraudulent charge amount imm...
# 4252           credit_card  recently submitted complaint around year regar...
# 32172          credit_card  made purchase discover card spring vacation mo...
# 39611       retail_banking  mst sent international money transfer moneygra...
# 4660           credit_card  purchased gift card kohl purchase hold placed ...
# 64310  mortgages_and_loans  fell behind monthly payment due illness wife c...
# 66842      debt_collection  allied trustee service state hoa gave approval...
# 34314      debt_collection  phone bill put name change liability cancelled...
# 2519       debt_collection  company claim owe money account company consid...
# 48166          credit_card     syncb car credit card mine ever used card sign
# 36843      debt_collection  keep receiving call access receivables managem...
# 45667       retail_banking                   screen wont load add bank detail
# 57798       retail_banking  good morning changed return check fee im reach...
# 60728      debt_collection  received letter collection company seem like t...
# 11524          credit_card  billed purchase made ref company exist except ...
# 42349      debt_collection  credit system placed collection account credit...
# 39178          credit_card  hello made purchase home depot fencing materia...
# 51270          credit_card  schedule take cruise cruise line choose amount...
# 52929  mortgages_and_loans  contacted ref home brother lived death informe...
# 36959      debt_collection  sxuppously debt buying account synchrony bank ...
# 17635  mortgages_and_loans  refinanced mortgage select portfolio servicing...
# 34903      debt_collection  opened separate secured account one due financ...
# 10878  mortgages_and_loans  due covid pandemic place employment working ma...
# 61488       retail_banking  said longer link pnc bank account unable pay rent
# 5026       debt_collection  today called nemos investigation collection az...
# 26670      debt_collection  cfpb complaint fraudulent year old heloc forec...
# 17036      debt_collection  sent letter portfolio recovery disputing alleg...
# 66576          credit_card  cancelled account based response email problem...
# 56064          credit_card  paypal synchrony paypal fl response previous c...
# 8303       debt_collection  select portfolio servicing attempt collect deb...
# 35540          credit_card  round trip airline ticket purchase using comen...
# 50274          credit_card  citibank closing account never missed payment ...

# %%
#Preprocessing.
df.fillna('', inplace=True)

# %%
df['narrative']=df['narrative'].str.replace('[^\w\s]', '') 
df['narrative']=df['narrative'].str.replace('\s+', ' ') 
df['narrative']=df['narrative'].str.replace('^\s+', '') 
df['narrative']=df['narrative'].str.replace('\s+$', '') 
df['narrative']=df['narrative'].str.lower()
df.head(20)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14992\2044865566.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['narrative']=df['narrative'].str.replace('[^\w\s]', '') #removing punctuations.
# C:\Users\User\AppData\Local\Temp\ipykernel_14992\2044865566.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['narrative']=df['narrative'].str.replace('\s+', ' ') #removing extra spaces.
# C:\Users\User\AppData\Local\Temp\ipykernel_14992\2044865566.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['narrative']=df['narrative'].str.replace('^\s+', '') #removing spaces from start.
# C:\Users\User\AppData\Local\Temp\ipykernel_14992\2044865566.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['narrative']=df['narrative'].str.replace('\s+$', '') #removing spaces from the end.
#                 product                                          narrative
# 0   mortgages_and_loans  applied mortgage refinance understand process ...
# 1       debt_collection  received letter demanding payment medical debt...
# 2       debt_collection  car accident fault year old financial help use...
# 3       debt_collection  bad financial shape stemming bad employment si...
# 4       debt_collection  reliant capital solution repeatly call spouse ...
# 5       debt_collection  called company numerous time debt mine sent th...
# 6       debt_collection  mentioned debt collecting agency sent letter d...
# 7           credit_card  late fee accumulated nearly extra fee deferred...
# 8           credit_card  purchased ticket cancelled event requested ref...
# 9       debt_collection  national service bureau threatened jail time r...
# 10      debt_collection  transworld system called repeatedly explained ...
# 11      debt_collection  receiving phone call abc financial regarding o...
# 12       retail_banking  hello used transfer money closed account go ba...
# 13      debt_collection  mailed notice acceptance negotiable instrument...
# 14  mortgages_and_loans  made mortgage payment bank america using coupo...
# 15       retail_banking  may concern take corrective action believe squ...
# 16  mortgages_and_loans  signed va refinance loan pennymac set closing ...
# 17          credit_card  hi thank helping relia debit card issued unemp...
# 18       retail_banking  applied cash loan lending club unaware would m...
# 19  mortgages_and_loans  applied refinance fha loan conventional loan c...

# %%
#Tokenization
import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.corpus import stopwords as sw

stop=set(sw.words('english'))


df['narrative'] = df['narrative'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
# Feature extraction
from sklearn.feature_extraction.text import TfidfVectorizer as tv
tfidf_vec = tv()
tfidf=tfidf_vec.fit_transform(df['narrative'])

# %%
#modelling
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(tfidf, df['product'], test_size=0.2, random_state=42)

# %%
#decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
param_grid = {'max_depth': [5, 10, 15], 'criterion': ['gini', 'entropy']}
grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose = 3)
grid.fit(x_train, y_train)
grid.best_params_
grid_predictions = grid.predict(x_test)
print("The accuracy score is:", accuracy_score(y_test, grid_predictions))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END .......criterion=gini, max_depth=5;, score=0.738 total time=   6.2s
# [CV 2/5] END .......criterion=gini, max_depth=5;, score=0.739 total time=   6.1s
# [CV 3/5] END .......criterion=gini, max_depth=5;, score=0.736 total time=   5.2s
# [CV 4/5] END .......criterion=gini, max_depth=5;, score=0.742 total time=   6.1s
# [CV 5/5] END .......criterion=gini, max_depth=5;, score=0.734 total time=   6.3s
# [CV 1/5] END ......criterion=gini, max_depth=10;, score=0.785 total time=  12.0s
# [CV 2/5] END ......criterion=gini, max_depth=10;, score=0.788 total time=  15.1s
# [CV 3/5] END ......criterion=gini, max_depth=10;, score=0.785 total time=  18.6s
# [CV 4/5] END ......criterion=gini, max_depth=10;, score=0.788 total time=  17.5s
# [CV 5/5] END ......criterion=gini, max_depth=10;, score=0.784 total time=  17.3s
# [CV 1/5] END ......criterion=gini, max_depth=15;, score=0.807 total time=  26.3s
# [CV 2/5] END ......criterion=gini, max_depth=15;, score=0.809 total time=  24.3s
# [CV 3/5] END ......criterion=gini, max_depth=15;, score=0.808 total time=  25.1s
# [CV 4/5] END ......criterion=gini, max_depth=15;, score=0.806 total time=  24.4s
# [CV 5/5] END ......criterion=gini, max_depth=15;, score=0.804 total time=  23.9s
# [CV 1/5] END ....criterion=entropy, max_depth=5;, score=0.738 total time=   7.7s
# [CV 2/5] END ....criterion=entropy, max_depth=5;, score=0.739 total time=   8.5s
# [CV 3/5] END ....criterion=entropy, max_depth=5;, score=0.733 total time=   8.4s
# [CV 4/5] END ....criterion=entropy, max_depth=5;, score=0.737 total time=   8.6s
# [CV 5/5] END ....criterion=entropy, max_depth=5;, score=0.732 total time=   8.6s
# [CV 1/5] END ...criterion=entropy, max_depth=10;, score=0.785 total time=  17.6s
# [CV 2/5] END ...criterion=entropy, max_depth=10;, score=0.785 total time=  18.5s
# [CV 3/5] END ...criterion=entropy, max_depth=10;, score=0.781 total time=  18.3s
# [CV 4/5] END ...criterion=entropy, max_depth=10;, score=0.783 total time=  18.9s
# [CV 5/5] END ...criterion=entropy, max_depth=10;, score=0.782 total time=  19.1s
# [CV 1/5] END ...criterion=entropy, max_depth=15;, score=0.807 total time=  34.8s
# [CV 2/5] END ...criterion=entropy, max_depth=15;, score=0.798 total time=  34.7s
# [CV 3/5] END ...criterion=entropy, max_depth=15;, score=0.800 total time=  33.3s
# [CV 4/5] END ...criterion=entropy, max_depth=15;, score=0.795 total time=  34.6s
# [CV 5/5] END ...criterion=entropy, max_depth=15;, score=0.797 total time=  33.0s
# The accuracy score is: 0.8107937399115728

# %%
#generating confusion matrix
from sklearn.metrics import confusion_matrix

cm_dt = confusion_matrix(y_test, grid_predictions)
print(cm_dt)
# Out:
# [[2283  334  157  265]
#  [ 226 4111  266   74]
#  [ 133  405 3108   99]
#  [ 321  272  144 2051]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,5))
sns.heatmap(cm_dt, annot=True, fmt="d", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
plt.show()

# %%
from sklearn.metrics import classification_report as cr
print(cr(y_test, grid_predictions))
# Out:
#                      precision    recall  f1-score   support
#
#         credit_card       0.77      0.75      0.76      3039
#     debt_collection       0.80      0.88      0.84      4677
# mortgages_and_loans       0.85      0.83      0.84      3745
#      retail_banking       0.82      0.74      0.78      2788
#
#            accuracy                           0.81     14249
#           macro avg       0.81      0.80      0.80     14249
#        weighted avg       0.81      0.81      0.81     14249
